# %% [markdown]
# # Adidas Sales Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adidas_sales = pd.read_excel(r"C:\Users\vishw\OneDrive\Desktop\Python Data Analyst Project\Adidas sales Datasets\Adidas US Sales Datasets.xlsx")

# %%
adidas_sales
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# ...

# %%
adidas_sales = adidas_sales.drop(adidas_sales.index[:3])

# %%
adidas_sales
# Out:
#       Unnamed: 0   Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 3            NaN     Retailer  Retailer ID         Invoice Date     Region
# 4            NaN  Foot Locker      1185732  2020-01-01 00:00:00  Northeast
# 5            NaN  Foot Locker      1185732  2020-01-02 00:00:00  Northeast
# 6            NaN  Foot Locker      1185732  2020-01-03 00:00:00  Northeast
# 7            NaN  Foot Locker      1185732  2020-01-04 00:00:00  Northeast
# ...          ...          ...          ...                  ...        ...
# 9647         NaN  Foot Locker      1185732  2021-01-24 00:00:00  Northeast
# 9648         NaN  Foot Locker      1185732  2021-01-24 00:00:00  Northeast
# 9649         NaN  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
# 9650         NaN  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
# 9651         NaN  Foot Locker      1185732  2021-02-22 00:00:00  Northeast
#
# ...

# %%
adidas_sales = adidas_sales.iloc[:, 1:]

# %%
adidas_sales
# Out:
#        Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4     Unnamed: 5  \
# 3        Retailer  Retailer ID         Invoice Date     Region          State
# 4     Foot Locker      1185732  2020-01-01 00:00:00  Northeast       New York
# 5     Foot Locker      1185732  2020-01-02 00:00:00  Northeast       New York
# 6     Foot Locker      1185732  2020-01-03 00:00:00  Northeast       New York
# 7     Foot Locker      1185732  2020-01-04 00:00:00  Northeast       New York
# ...           ...          ...                  ...        ...            ...
# 9647  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9648  Foot Locker      1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9649  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9650  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9651  Foot Locker      1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %%
new_header = adidas_sales.iloc[0]
adidas_sales = adidas_sales[1:]
adidas_sales.columns = new_header

# %%
adidas_sales = adidas_sales.reset_index(drop=True)

# %%
adidas_sales
# Out:
# 3        Retailer Retailer ID         Invoice Date     Region          State  \
# 0     Foot Locker     1185732  2020-01-01 00:00:00  Northeast       New York
# 1     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 2     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 3     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 4     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9643  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9647  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# ...

# %% [markdown]
# Data cleaning and preprocessing

# %%
adidas_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: object(13)
# memory usage: 980.0+ KB

# %%
adidas_sales = adidas_sales.drop_duplicates()

# %%
adidas_sales["Invoice Date"] = pd.to_datetime(adidas_sales["Invoice Date"])

# %%
coloms = ["Price per Unit","Units Sold","Total Sales","Operating Profit","Operating Margin"]
adidas_sales[coloms] = adidas_sales[coloms].astype(float)

# %%
adidas_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   float64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1.0+ MB

# %%
adidas_sales["Retailer ID"] = adidas_sales["Retailer ID"].astype(int)

# %%
adidas_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int32
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   float64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(5), int32(1), object(6)
# memory usage: 1017.6+ KB

# %%
adidas_sales.describe()
# Out:
# 3       Retailer ID  Price per Unit   Units Sold    Total Sales  \
# count  9.648000e+03     9648.000000  9648.000000    9648.000000
# mean   1.173850e+06       45.216625   256.930037   93273.437500
# std    2.636038e+04       14.705397   214.252030  141916.016727
# min    1.128299e+06        7.000000     0.000000       0.000000
# 25%    1.185732e+06       35.000000   106.000000    4254.500000
# 50%    1.185732e+06       45.000000   176.000000    9576.000000
# 75%    1.185732e+06       55.000000   350.000000  150000.000000
# max    1.197831e+06      110.000000  1275.000000  825000.000000
#
# 3      Operating Profit  Operating Margin
# count       9648.000000       9648.000000
# mean       34425.244761          0.422991
# std        54193.113713          0.097197
# min            0.000000          0.100000
# 25%         1921.752500          0.350000
# 50%         4371.420000          0.410000
# 75%        52062.500000          0.490000
# max       390000.000000          0.800000

# %%
adidas_sales
# Out:
# 3        Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
# 3           City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# Exploratoty Data Analysis(EDA)

# %% [markdown]
# Sales By Reatailers

# %%
adidas_sales["Retailer"].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %%
revenue_by_Retailer = adidas_sales.groupby("Retailer")['Total Sales'].sum()

# %%
fig, ax=plt.subplots()
ax.bar(revenue_by_Retailer.index , revenue_by_Retailer, color='#40D19A')
ax.set_xlabel("Retailers")
ax.set_ylabel("Sales")
ax.set_title("Total Sales By Retailers")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for i, v in enumerate(revenue_by_Retailer):
        ax.text(i, v, str(v), ha='center', va='bottom')

# %%
fig, ax=plt.subplots()
ax.pie(revenue_by_Retailer, startangle=90, labels=revenue_by_Retailer.index, autopct="%.0f%%")
ax.set_title("Total Sales By Retailers")
plt.show()

# %% [markdown]
# Sales By Products

# %%
adidas_sales["Product"].unique()
# Out:
# array(["Men's Street Footwear", "Men's Athletic Footwear",
#        "Women's Street Footwear", "Women's Athletic Footwear",
#        "Men's Apparel", "Women's Apparel"], dtype=object)

# %%
revenue_by_Product = adidas_sales.groupby("Product")['Total Sales'].sum()

# %%
fig, ax=plt.subplots()
ax.bar(revenue_by_Product.index , revenue_by_Product, color='#40D19A')
ax.set_xlabel("Product")
ax.set_ylabel("Sales")
ax.set_title("Total Sales By Product")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for i, v in enumerate(revenue_by_Product):
        ax.text(i, v, str(v), ha='center', va='bottom')
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax=plt.subplots()
ax.pie(revenue_by_Product, startangle=90, labels=revenue_by_Product.index, autopct="%.0f%%")
ax.set_title("Total Sales By Product")
plt.show()

# %% [markdown]
# Sales By Region

# %%
adidas_sales["Region"].unique()
# Out:
# array(['Northeast', 'South', 'West', 'Midwest', 'Southeast'], dtype=object)

# %%
revenue_by_Region = adidas_sales.groupby("Region")['Total Sales'].sum()

# %%
fig, ax=plt.subplots()
ax.bar(revenue_by_Region.index , revenue_by_Region, color='#40D19A')
ax.set_xlabel("Region")
ax.set_ylabel("Sales")
ax.set_title("Total Sales By Region")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
for i, v in enumerate(revenue_by_Region):
        ax.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
fig, ax=plt.subplots()
ax.pie(revenue_by_Region, startangle=90, labels=revenue_by_Region.index, autopct="%.0f%%")
ax.set_title("Total Sales By Region")
plt.show()

# %% [markdown]
# Profit By Each Retailers and Each Product

# %%
profit_by_Retailer = adidas_sales.groupby("Retailer")['Operating Profit'].sum()
profit_by_Product = adidas_sales.groupby("Product")['Operating Profit'].sum()

# %%
fig, ax=plt.subplots(2,2,figsize=(15,10))



ax[0][0].bar(profit_by_Retailer.index , profit_by_Retailer, color='#40D19A')
ax[0][0].set_xlabel("Retailers")
ax[0][0].set_ylabel("Sales")
ax[0][0].set_title("Total Profit By Each Retailers")
ax[0][0].spines['right'].set_visible(False)
ax[0][0].spines['top'].set_visible(False)
for i, v in enumerate(profit_by_Retailer):
        ax[0][0].text(i, v, str(v), ha='center', va='bottom')

ax[1][0].pie(profit_by_Retailer, startangle=90, labels=profit_by_Retailer.index, autopct="%.0f%%")
ax[1][0].set_title("Total Profit By Each Retailers")
        

    
ax[0][1].bar(profit_by_Product.index , profit_by_Product, color='#40D19A')
ax[0][1].set_xlabel("Products")
ax[0][1].set_ylabel("Sales")
ax[0][1].set_title("Total Profit By Each Products")
ax[0][1].spines['right'].set_visible(False)
ax[0][1].spines['top'].set_visible(False)
for i, v in enumerate(profit_by_Product):
        ax[0][1].text(i, v, str(v), ha='center', va='bottom')

ax[1][1].pie(profit_by_Product, startangle=90, labels=profit_by_Product.index, autopct="%.0f%%")
ax[1][1].set_title("Total Profit By Each Products")

plt.show()
